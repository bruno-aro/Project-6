# %% [markdown]
# ## Your Task!
#
# You will use BeautifulSoup to scrape data from [U.Today](https://u.today/) financial news. Use the search feature to find results specific to your chosen cryptocurrency. You can also add additional filters, notice how they are added to the URL! The purpose of this exercise is to collect data, don't worry when the data you're collecting is not the most relevant.

# %%
import requests
from bs4 import BeautifulSoup

url = "https://u.today/search/node?keys=btc"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# %%
btc_cards = soup.select("div.news__item")

titles = []
for card in btc_cards:
    title = card.find("a", class_="news__item-body")
    if title:
        titles.append(title.get_text(strip=True))

titles
# Out:
# ['Bitcoin (BTC) Secures Biggest Fakeout of Q4, 2025: Will It Destroy $100,000?',
#  "'Not the Best Financial Advice' Peter McCormack Slams Peter Schiff's BTC Criticism",
#  "Crypto Market Prediction: Is This Biggest XRP Comeback in History? Bitcoin (BTC) Breaks $115,000 Like It's Nothing, Shiba Inu (SHIB): Not Adding Zero",
#  "XRP Holders Didn't Panic Despite 50% Price Drop, Peter Brandt Issues Bullish Verdict on Bitcoin (BTC), Shiba Inu (SHIB) Back in 2023 — Crypto News Digest",
#  'Bitcoin (BTC) Price Analysis for October 13',
#  "Legendary Trader Peter Brandt Adds '5% BTC' to Retirement Plans",
#  'Crypto Market Prediction: Is Shiba Inu (SHIB) Bottom Officially Reached? Bitcoin (BTC) Is Stronger Than You Think, Is XRP Bound to $1 Now?',
#  'BTC and ETH Rally as $257 Million Worth of Shorts Get Liquidated',
#  'Bitcoin (BTC) Price Analysis for October 12',
#  'Bitcoin (BTC) Price Could Plunge to $75,000, Schiff Predicts',
#  'Bitcoin (BTC) Price Analysis for October 11',
#  'BTC vs. ETH: Why Ethereum Price Lags Behind Bitcoin',
#  "Morning Crypto Report: 'Bitcoin Jesus' Free? XRP Bulls Crushed in 3,192% Liquidation Imbalance Bloodbath, Whale Bets $600 Million Against BTC",
#  'Crypto Market Prediction: XRP to Enter Freefall, Critical Support Lost? Bitcoin (BTC) Hits $120,000 Top, Shiba Inu (SHIB) Bullish Reversal Starts Here',
#  'Peter Brandt Sounds Alarm on Bitcoin (BTC), New XRP ETF with 3x Leverage Proposed, Cardano Founder Predicts Shift in Altcoin Season — Crypto News Digest',
#  'Bitcoin (BTC) Price Analysis for October 9',
#  'Bitcoin (BTC) Price to $112,000? Upside Rally Still Intact',
#  'XRP Drops Out of Top 3, Dogecoin Creator Breaks Silence on Bitcoin (BTC) Price, Shiba Inu (SHIB) Sees 70% Spike in 48 Hours — Crypto News Digest',
#  'Can Bitcoin (BTC) Hit $150,000? 3 Key Factors',
#  'Crypto Market Prediction: Bitcoin (BTC) Troubled at $123,000, Shiba Inu (SHIB) Hits Key Moment After Four Months, Ethereum (ETH) to Hit $5,000 After These Three',
#  'Bitcoin (BTC) Price Analysis for October 7',
#  'Morning Crypto Report: $610 Million XRP Surprise by Ripple, Bitcoin (BTC) Smashes $126,000 Record, Shiba Inu (SHIB) Faces Survival Questions',
#  'Crypto Market Prediction: XRP Delivers Legendary Price Pattern, Ethereum (ETH) Consolidates for $4,500, No $150,000 Bitcoin (BTC)?',
#  'Bitcoin (BTC) Price Analysis for October 6',
#  'Crypto Market Prediction: Bitcoin (BTC) ATH Is Nothing, XRP Begins $5 Run, Shiba Inu (SHIB) No Choice at $0.000013',
#  'Bitcoin (BTC) Price Prediction for October 5',
#  '‘Good Chance’ BTC Tops Several Weeks from Now, Analysts Claim',
#  'BREAKING: Bitcoin (BTC) Finally Hits New ATH; Is $135,000 Likely?',
#  'Bitcoin (BTC) Price Prediction for October 4',
#  'Dogecoin (DOGE) Confirms First Golden Cross, Shiba Inu (SHIB) Downtrend Ending, Bitcoin (BTC) Price Hits $120,000, Eyes New ATH — Crypto News Digest',
#  'Bitcoin (BTC) to Hit $200,000 by End of 2025, Standard Chartered Predicts',
#  'Bitcoin (BTC) Price Prediction for October 3',
#  'Bitcoin (BTC) Can Even Hit $200,000, According to Popular Indicator',
#  "Crypto Market Prediction: XRP Ready for $3, Bitcoin (BTC) Can't Handle It, Is Shiba Inu (SHIB) Ready for $0.00002?",
#  "$3,700,000,000 BTC Profit-Taking Shakes Crypto Market, What's Next?",
#  "Bitcoin's (BTC) Profit-Taking Stage Comes, USDT/USDC Duopoly Might End Soon, Tether's Cap to $1 Trillion: Crypto News Recap",
#  'BREAKING: CME Group to Offer 24/7 Trading for XRP, SOL, BTC, and Other Crypto Futures',
#  'Crypto Market Prediction: Bitcoin (BTC) to Rocket to $130,000? Shiba Inu (SHIB) Hits $0.000012 Breakout, XRP Breaks 5 Resistances in 1 Move',
#  'Ripple CTO Resigns, XRP Bear Destroyed After Massive Short, Bitcoin (BTC) Price to $150,000 — Crypto News Digest',
#  'Bitcoin (BTC) Price Analysis for October 1',
#  '$125 Billion Satoshi BTC Wallet Attracts Speculation Amid XRP, Market Developments',
#  "Crypto Market Prediction: XRP Should Not Celebrate Too Early, Did Ethereum (ETH) Secure $4,200? This Is Bitcoin's (BTC) $113,000 Chance",
#  'Bitcoin (BTC) Price Analysis for September 29',
#  'Crypto Market Prediction:  Shiba Inu (SHIB) in Free Fall to Add Zero, Ethereum (ETH) Secures $4,000, Bitcoin (BTC): $110,000 Comeback Attempt',
#  'Bitcoin (BTC) Price Prediction for September 28',
#  'First Bitcoiner in Space Says BTC Will Survive Quantum Computing',
#  '$200,000 BTC: Mike Novogratz Predicts Bitcoin Price Surge',
#  'Bitcoin (BTC) Price Prediction for September 27',
#  "Crypto Market Prediction: Ethereum (ETH) Can Start $5,000 Path Here, XRP Welcomes $2.60, Bitcoin's (BTC) Bullish $108,000 Reversal",
#  'Bitcoin (BTC) Price Prediction for September 26',
#  'World AI Show Welcomes MIDA as Strategic Investment Partner, Strengthening Malaysia’s Position as AI & Investment Hub',
#  'Intelligence Awakens, Civilization Sets Sail: ARK DAO Launches, Opening a New Era of AI and Community Co-Governance in Decentralization',
#  'ViaBTC Unveils Enhanced Collateralized Loan Service for Global Miners',
#  'How High Will Bitcoin (BTC) Price Go In 2025?',
#  'Bitget Wallet, The All-in-One Crypto Wallet for Everyday Mobile Users: Big Review',
#  'From Exchange to Ecosystem: HTX Redefines What CEX Means in the New Crypto Cycle',
#  'Silent Data Ethereum L2 Launched by Applied Blockchain: Details',
#  'Redefining Role of CEXes and Building Trust Gateway in Web3 Era: Big Interview with Coinstore CEO Johnson Zhao',
#  'Urgent Shiba Inu Alert Issued as Fake SHIB Sites Target Wallets: Details',
#  'Bitcoin (BTC) Secures Biggest Fakeout of Q4, 2025: Will It Destroy $100,000?',
#  "'Not the Best Financial Advice' Peter McCormack Slams Peter Schiff's BTC Criticism"]

# %%
authors = []

for card in btc_cards:
    author_tag = card.find("a", class_="humble humble--author")
    if author_tag:
        authors.append(author_tag.get_text(strip=True))
    else:
        authors.append(None)

authors
# Out:
# ['Arman Shirinyan',
#  'Godfrey Benjamin',
#  'Arman Shirinyan',
#  'Dan Burgin',
#  'Denys Serhiichuk',
#  'Godfrey Benjamin',
#  'Arman Shirinyan',
#  'Alex Dovbnya',
#  'Denys Serhiichuk',
#  'Alex Dovbnya',
#  'Denys Serhiichuk',
#  'Dan Burgin',
#  'Gamza Khanzadaev',
#  'Arman Shirinyan',
#  'Dan Burgin',
#  'Denys Serhiichuk',
#  'Godfrey Benjamin',
#  'Dan Burgin',
#  'Arman Shirinyan',
#  'Arman Shirinyan',
#  'Denys Serhiichuk',
#  'Gamza Khanzadaev',
#  'Arman Shirinyan',
#  'Denys Serhiichuk',
#  'Arman Shirinyan',
#  'Denys Serhiichuk',
#  'Alex Dovbnya',
#  'Alex Dovbnya',
#  'Denys Serhiichuk',
#  'Dan Burgin',
#  'Alex Dovbnya',
#  'Denys Serhiichuk',
#  'Arman Shirinyan',
#  'Arman Shirinyan',
#  'Tomiwabold Olajide',
#  'Vladislav Sopov',
#  'Alex Dovbnya',
#  'Arman Shirinyan',
#  'Dan Burgin',
#  'Denys Serhiichuk',
#  'Tomiwabold Olajide',
#  'Arman Shirinyan',
#  'Denys Serhiichuk',
#  'Arman Shirinyan',
#  'Denys Serhiichuk',
#  'Alex Dovbnya',
#  'Dan Burgin',
#  'Denys Serhiichuk',
#  'Arman Shirinyan',
#  'Denys Serhiichuk',
#  None,
#  None,
#  None,
#  'Dan Burgin',
#  'Vladislav Sopov',
#  'U.Today Editorial Team',
#  'Vladislav Sopov',
#  'U.Today Editorial Team',
#  'Alex Dovbnya',
#  'Alex Dovbnya',
#  'Alex Dovbnya']

# %%
dates = []

for card in btc_cards:
    date_tag = card.find("div", class_="humble")
    if date_tag:
        dates.append(date_tag.get_text(strip=True))
    else:
        dates.append(None)

dates
# Out:
# ['Oct 14, 2025 - 11:23',
#  'Oct 14, 2025 - 11:13',
#  'Oct 14, 2025 - 0:01',
#  'Oct 13, 2025 - 18:50',
#  'Oct 13, 2025 - 16:17',
#  'Oct 13, 2025 - 16:14',
#  'Oct 13, 2025 - 0:01',
#  'Oct 12, 2025 - 18:55',
#  'Oct 12, 2025 - 14:44',
#  'Oct 12, 2025 - 10:19',
#  'Oct 11, 2025 - 15:03',
#  'Oct 11, 2025 - 6:50',
#  'Oct 10, 2025 - 11:47',
#  'Oct 10, 2025 - 0:01',
#  'Oct 9, 2025 - 18:03',
#  'Oct 9, 2025 - 15:44',
#  'Oct 9, 2025 - 15:42',
#  'Oct 8, 2025 - 16:31',
#  'Oct 8, 2025 - 13:26',
#  'Oct 8, 2025 - 0:01',
#  'Oct 7, 2025 - 14:12',
#  'Oct 7, 2025 - 10:17',
#  'Oct 7, 2025 - 0:01',
#  'Oct 6, 2025 - 15:47',
#  'Oct 6, 2025 - 0:01',
#  'Oct 5, 2025 - 15:41',
#  'Oct 5, 2025 - 15:04',
#  'Oct 5, 2025 - 5:36',
#  'Oct 4, 2025 - 16:32',
#  'Oct 3, 2025 - 22:57',
#  'Oct 3, 2025 - 16:34',
#  'Oct 3, 2025 - 14:03',
#  'Oct 3, 2025 - 13:09',
#  'Oct 3, 2025 - 0:01',
#  'Oct 2, 2025 - 18:48',
#  'Oct 2, 2025 - 15:30',
#  'Oct 2, 2025 - 14:16',
#  'Oct 2, 2025 - 0:01',
#  'Oct 1, 2025 - 16:26',
#  'Oct 1, 2025 - 15:17',
#  'Oct 1, 2025 - 11:10',
#  'Oct 1, 2025 - 0:01',
#  'Sep 29, 2025 - 14:03',
#  'Sep 29, 2025 - 0:01',
#  'Sep 28, 2025 - 13:24',
#  'Sep 28, 2025 - 10:31',
#  'Sep 27, 2025 - 11:24',
#  'Sep 27, 2025 - 10:31',
#  'Sep 27, 2025 - 0:01',
#  'Sep 26, 2025 - 16:31',
#  None,
#  None,
#  None,
#  'Jul 28, 2025 - 2:20',
#  'Jul 15, 2025 - 11:00',
#  'Jul 14, 2025 - 4:30',
#  'Jul 11, 2025 - 10:02',
#  'Jul 7, 2025 - 12:18',
#  'Oct 14, 2025 - 11:29',
#  'Oct 14, 2025 - 11:23',
#  'Oct 14, 2025 - 11:13']

# %%
links = []

for card in btc_cards:
    link_tag = card.find("a", class_="news__item-body")
    if link_tag and link_tag.has_attr("href"):
        links.append(link_tag["href"])
    else:
        links.append(None)

links
# Out:
# ['https://u.today/bitcoin-btc-secures-biggest-fakeout-of-q4-2025-will-it-destroy-100000',
#  'https://u.today/not-the-best-financial-advice-peter-mccormack-slams-peter-schiffs-btc-criticism',
#  'https://u.today/crypto-market-prediction-is-this-biggest-xrp-comeback-in-history-bitcoin-btc-breaks-115000-like-its',
#  'https://u.today/xrp-holders-didnt-panic-despite-50-price-drop-peter-brandt-issues-bullish-verdict-on-bitcoin-btc',
#  'https://u.today/bitcoin-btc-price-analysis-for-october-13-0',
#  'https://u.today/legendary-trader-peter-brandt-adds-5-btc-to-retirement-plans',
#  'https://u.today/crypto-market-prediction-is-shiba-inu-shib-bottom-officially-reached-bitcoin-btc-is-stronger-than',
#  'https://u.today/btc-and-eth-rally-as-257-million-worth-of-shorts-get-liquidated',
#  'https://u.today/bitcoin-btc-price-analysis-for-october-12-0',
#  'https://u.today/bitcoin-btc-price-could-plunge-to-75000-schiff-predicts',
#  'https://u.today/bitcoin-btc-price-analysis-for-october-11',
#  'https://u.today/opinions/btc-vs-eth-why-ethereum-price-lags-behind-bitcoin',
#  'https://u.today/morning-crypto-report-bitcoin-jesus-free-xrp-bulls-crushed-in-3192-liquidation-imbalance-bloodbath',
#  'https://u.today/crypto-market-prediction-xrp-to-enter-freefall-critical-support-lost-bitcoin-btc-hits-120000-top',
#  'https://u.today/peter-brandt-sounds-alarm-on-bitcoin-btc-new-xrp-etf-with-3x-leverage-proposed-cardano-founder',
#  'https://u.today/bitcoin-btc-price-analysis-for-october-9-0',
#  'https://u.today/bitcoin-btc-price-to-112000-upside-rally-still-intact',
#  'https://u.today/xrp-drops-out-of-top-3-dogecoin-creator-breaks-silence-on-bitcoin-price-shiba-inu-shib-sees-70',
#  'https://u.today/can-bitcoin-btc-hit-150000-3-key-factors',
#  'https://u.today/crypto-market-prediction-bitcoin-btc-troubled-at-123000-shiba-inu-shib-hits-key-moment-after-four',
#  'https://u.today/bitcoin-btc-price-analysis-for-october-7-0',
#  'https://u.today/morning-crypto-report-610-million-xrp-surprise-by-ripple-bitcoin-btc-smashes-126000-record-shiba',
#  'https://u.today/crypto-market-prediction-xrp-delivers-legendary-price-pattern-ethereum-eth-consolidates-for-4500-no',
#  'https://u.today/bitcoin-btc-price-analysis-for-october-6',
#  'https://u.today/crypto-market-prediction-bitcoin-btc-ath-is-nothing-xrp-begins-5-run-shiba-inu-shib-no-choice-at',
#  'https://u.today/bitcoin-btc-price-prediction-for-october-5-0',
#  'https://u.today/good-chance-btc-tops-several-weeks-from-now-analysts-claim',
#  'https://u.today/breaking-bitcoin-btc-finally-hits-new-ath-is-135000-likely',
#  'https://u.today/bitcoin-btc-price-prediction-for-october-4',
#  'https://u.today/dogecoin-doge-confirms-first-golden-cross-shiba-inu-shib-downtrend-ending-bitcoin-btc-price-hits',
#  'https://u.today/bitcoin-btc-to-hit-200000-by-end-of-2025-standard-chartered-predicts',
#  'https://u.today/bitcoin-btc-price-prediction-for-october-3',
#  'https://u.today/bitcoin-btc-can-even-hit-200000-according-to-popular-indicator',
#  'https://u.today/crypto-market-prediction-xrp-ready-for-3-bitcoin-btc-cant-handle-it-is-shiba-inu-shib-ready-for',
#  'https://u.today/3700000000-btc-profit-taking-shakes-crypto-market-whats-next',
#  'https://u.today/bitcoins-btc-profit-taking-stage-comes-usdtusdc-duopoly-might-end-soon-tethers-cap-to-1-trillion',
#  'https://u.today/breaking-cme-group-to-offer-247-trading-for-xrp-sol-btc-and-other-crypto-futures',
#  'https://u.today/crypto-market-prediction-bitcoin-btc-to-rocket-to-130000-shiba-inu-shib-hits-0000012-breakout-xrp',
#  'https://u.today/ripple-cto-resigns-xrp-bear-destroyed-after-massive-short-bitcoin-btc-price-to-150000-crypto-news',
#  'https://u.today/bitcoin-btc-price-analysis-for-october-1',
#  'https://u.today/125-billion-satoshi-btc-wallet-attracts-speculation-amid-xrp-market-developments',
#  'https://u.today/crypto-market-prediction-xrp-should-not-celebrate-too-early-did-ethereum-eth-secure-4200-this-is',
#  'https://u.today/bitcoin-btc-price-analysis-for-september-29-0',
#  'https://u.today/crypto-market-prediction-shiba-inu-shib-in-free-fall-to-add-zero-ethereum-eth-secures-4000-bitcoin',
#  'https://u.today/bitcoin-btc-price-prediction-for-september-28-0',
#  'https://u.today/first-bitcoiner-in-space-says-btc-will-survive-quantum-computing',
#  'https://u.today/200000-btc-mike-novogratz-predicts-bitcoin-price-surge',
#  'https://u.today/bitcoin-btc-price-prediction-for-september-27-0',
#  'https://u.today/crypto-market-prediction-ethereum-eth-can-start-5000-path-here-xrp-welcomes-260-bitcoins-btc',
#  'https://u.today/bitcoin-btc-price-prediction-for-september-26',
#  'https://u.today/press-releases/world-ai-show-welcomes-mida-as-strategic-investment-partner-strengthening-malaysias',
#  'https://u.today/press-releases/intelligence-awakens-civilization-sets-sail-ark-dao-launches-opening-a-new-era-of-ai',
#  'https://u.today/press-releases/viabtc-unveils-enhanced-collateralized-loan-service-for-global-miners',
#  'https://u.today/opinions/how-high-will-bitcoin-btc-price-go-in-2025',
#  'https://u.today/reviews/bitget-wallet-the-all-in-one-crypto-wallet-for-everyday-mobile-users-big-review',
#  'https://u.today/reviews/from-exchange-to-ecosystem-htx-redefines-what-cex-means-in-the-new-crypto-cycle',
#  'https://u.today/reviews/silent-data-ethereum-l2-launched-by-applied-blockchain-details',
#  'https://u.today/interviews/redefining-role-of-cexes-and-building-trust-gateway-in-web3-era-big-interview-with-coinstore-ceo',
#  'https://u.today/urgent-shiba-inu-alert-issued-as-fake-shib-sites-target-wallets-details',
#  'https://u.today/bitcoin-btc-secures-biggest-fakeout-of-q4-2025-will-it-destroy-100000',
#  'https://u.today/not-the-best-financial-advice-peter-mccormack-slams-peter-schiffs-btc-criticism']

# %%
import pandas as pd

df = pd.DataFrame({
    "ID":range(1, len(titles) + 1),
    "Title": titles,
    "Author": authors,
    "Link": links,
    "Date": dates
})

# %%
df["Dates.N"] = pd.to_datetime(
    df["Date"].str.replace("–", "-", regex=False).str.strip(),
    format="%b %d, %Y - %H:%M",
    errors="coerce"
)

# %%
df = df[["ID", "Title", "Author", "Link", "Dates.N"]]

# %%
df.head()
#df.tail()
#df.info()
# Out:
#    ID                                              Title            Author  \
# 0   1  Bitcoin (BTC) Secures Biggest Fakeout of Q4, 2...   Arman Shirinyan
# 1   2  'Not the Best Financial Advice' Peter McCormac...  Godfrey Benjamin
# 2   3  Crypto Market Prediction: Is This Biggest XRP ...   Arman Shirinyan
# 3   4  XRP Holders Didn't Panic Despite 50% Price Dro...        Dan Burgin
# 4   5        Bitcoin (BTC) Price Analysis for October 13  Denys Serhiichuk
#
#                                                 Link             Dates.N
# 0  https://u.today/bitcoin-btc-secures-biggest-fa... 2025-10-14 11:23:00
# 1  https://u.today/not-the-best-financial-advice-... 2025-10-14 11:13:00
# 2  https://u.today/crypto-market-prediction-is-th... 2025-10-14 00:01:00
# 3  https://u.today/xrp-holders-didnt-panic-despit... 2025-10-13 18:50:00
# 4  https://u.today/bitcoin-btc-price-analysis-for... 2025-10-13 16:17:00

# %%
df[["Date", "Dates.N"]].head()
# Out:
#                    Date             Dates.N
# 0  Oct 14, 2025 - 11:23 2025-10-14 11:23:00
# 1  Oct 14, 2025 - 11:13 2025-10-14 11:13:00
# 2   Oct 14, 2025 - 0:01 2025-10-14 00:01:00
# 3  Oct 13, 2025 - 18:50 2025-10-13 18:50:00
# 4  Oct 13, 2025 - 16:17 2025-10-13 16:17:00

# %%
df.to_csv("btc_data_news.csv", index=False)
